# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Exploratory Data Analysis

# %%
df = pd.read_csv(r"C:\Users\tangu\Downloads\car data.csv")
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
#Check statistics of data set
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Driven_kms       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.642584   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %% [markdown]
# Data Check and Transforming

# %%
# Check null values
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
# check duplication
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
# drop duplicate values
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# checking the distribution of categorical data
print(df['Fuel_Type'].value_counts())
print(df['Selling_type'].value_counts())
print(df['Transmission'].value_counts())
# Out:
# Fuel_Type
# Petrol    239
# Diesel     58
# CNG         2
# Name: count, dtype: int64
# Selling_type
# Dealer        193
# Individual    106
# Name: count, dtype: int64
# Transmission
# Manual       260
# Automatic     39
# Name: count, dtype: int64

# %%
# encoding "Fuel_Type" Column
df.replace({'Fuel_Type':{'Petrol':0,'Diesel':1,'CNG':2}},inplace=True)

# encoding "Seller_Type" Column
df.replace({'Selling_type':{'Dealer':0,'Individual':1}},inplace=True)

# encoding "Transmission" Column
df.replace({'Transmission':{'Manual':0,'Automatic':1}},inplace=True)

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms  Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000          0
# 1      sx4  2013           4.75           9.54       43000          1
# 2     ciaz  2017           7.25           9.85        6900          0
# 3  wagon r  2011           2.85           4.15        5200          0
# 4    swift  2014           4.60           6.87       42450          1
#
#    Selling_type  Transmission  Owner
# 0             0             0      0
# 1             0             0      0
# 2             0             0      0
# 3             0             0      0
# 4             0             0      0

# %% [markdown]
# Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Price distribution
plt.figure(figsize=(10,6))
sns.histplot(df['Selling_Price'], kde=True)
plt.title('Car Price Distribution')
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm',fmt=".2f")
plt.title('Feature Correlation')
plt.show()

# %%
# Pairplot of numerical features
sns.pairplot(df[['Selling_Price', 'Present_Price', 'Driven_kms']])
plt.show()

# %%
# Boxplots for categorical features
# Selling Price by Fuel Type
plt.figure(figsize=(10, 6))
sns.boxplot(x='Fuel_Type', y='Selling_Price', data=df)
plt.title('Selling Price by Fuel Type')
plt.show()

# Selling Price by Transmission Type
plt.figure(figsize=(10, 6))
sns.boxplot(x='Transmission', y='Selling_Price', data=df)
plt.title('Selling Price by Transmission Type')
plt.show()

# %%
# Calculate average price for each car model
avg_prices_by_car = df.groupby('Car_Name')['Selling_Price'].mean().sort_values(ascending=False)

# Plot top car models by average price
Top_car_models = avg_prices_by_car.head(15)
plt.figure(figsize=(10, 6))
sns.barplot(x=Top_car_models.values, y=Top_car_models.index)
plt.title('Top Car Models by Average Price')
plt.xlabel('Average Price')
plt.ylabel('Car Model')
plt.tight_layout()
plt.show()

# %% [markdown]
# Train the Model

# %%
X = df.drop(['Car_Name','Selling_Price'],axis=1)
y = df['Selling_Price']

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=13)

# model_1 traning
model_1 = DecisionTreeRegressor()
model_1.fit(X_train, y_train)

# Prediction
y_pred = model_1.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error (MSE):", mse)
print("R^2-squared (R^2):",r2)
# Out:
# Mean Squared Error (MSE): 1.9147633333333338
# R^2-squared (R^2): 0.9136973646983771

# %%
from sklearn.ensemble import RandomForestRegressor

# model_2 training
model_2 = RandomForestRegressor()
model_2.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# prediction
y_pred = model_2.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print('Mean Squared Error:', mse)
print('R^2-squared:', r2)
# Out:
# Mean Squared Error: 1.686201431333336
# R^2-squared: 0.9239991571594912

# %%
# Plot feature importance
feature_imps=pd.Series(model_2.feature_importances_,index=X.columns)
plt.figure(figsize=(10,8))
feature_imps.plot(kind='barh')
plt.ylabel('Features')
plt.xlabel('Importances')
plt.title('Feature Importances as per the Model')
plt.show()

# %%
pred_df=pd.DataFrame({'Actual Price':y_test,'Predicted Price':y_pred,'Difference':y_test-y_pred})
pred_df
# Out:
#      Actual Price  Predicted Price  Difference
# 265          6.50           8.1570     -1.6570
# 120          1.05           0.9393      0.1107
# 199          0.12           0.1886     -0.0686
# 81           4.75           5.2405     -0.4905
# 31           2.35           2.8335     -0.4835
# 83          12.50           8.4255      4.0745
# 52          18.00          15.6606      2.3394
# 62          18.75          21.3070     -2.5570
# 59          19.99          23.7550     -3.7650
# 259          3.90           3.9745     -0.0745
# 228          4.95           5.1375     -0.1875
# 172          0.40           0.4101     -0.0101
# 160          0.45           0.4524     -0.0024
# 12           7.50           7.1708      0.3292
# 13           6.10           5.7650      0.3350
# 213          2.90           3.3865     -0.4865
# 251          5.00           5.3906     -0.3906
# 297          4.00           4.2025     -0.2025
# 177          0.35           0.4245     -0.0745
# 194          0.20           0.4071     -0.2071
# 80          14.73          11.1056      3.6244
# 286          5.65           5.7075     -0.0575
# 174          0.38           0.3538      0.0262
# 9            7.45           6.8160      0.6340
# 270          4.10           4.3408     -0.2408
# 130          0.75           0.6603      0.0897
# 281          2.10           2.7089     -0.6089
# 35           2.95           3.4415     -0.4915
# 216          2.90           3.0615     -0.1615
# 99           9.65           7.6780      1.9720
# 47           1.05           2.3065     -1.2565
# 185          0.25           0.3693     -0.1193
# 250         12.90           9.4031      3.4969
# 287          5.75           4.8605      0.8895
# 152          0.50           0.4818      0.0182
# 7            6.50           6.5845     -0.0845
# 211         11.75           9.2155      2.5345
# 209          4.85           5.2005     -0.3505
# 205          5.25           5.3435     -0.0935
# 290          4.50           5.0905     -0.5905
# 244          5.95           5.7902      0.1598
# 285          7.40           6.5215      0.8785
# 114          1.15           1.1343      0.0157
# 271          3.00           3.2545     -0.2545
# 221          4.50           4.1656      0.3344
# 55           3.60           3.9075     -0.3075
# 241          4.75           4.2570      0.4930
# 150          0.50           0.4951      0.0049
# 207          5.15           4.1465      1.0035
# 237         11.25           8.3890      2.8610
# 72           7.45           6.7150      0.7350
# 256         10.25           9.0121      1.2379
# 137          0.65           0.5129      0.1371
# 255          3.00           3.1765     -0.1765
# 248          4.00           2.8325      1.1675
# 42           1.95           2.5170     -0.5670
# 154          0.50           0.6208     -0.1208
# 68           4.35           4.8969     -0.5469
# 116          1.10           1.0678      0.0322
# 24           2.90           2.5510      0.3490

# %%
# Create plot
plt.figure(figsize=(10, 5))
sns.regplot(x=y_test, y=y_pred)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual Prices vs Predicted Prices")
plt.show()

# %% [markdown]
# Best Model
# Best model is Random Forest Regressor
#
# - MSE: 1.6 (vs Decision Tree's 1.92) → More precise predictions
#
# - R²: 92.3% (vs Decision Tree's 91.3%) → Better fit to data
#
# More stable than single Decision Tree (reduces overfitting risk)
